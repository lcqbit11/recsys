# %%
#!/usr/bin/env python
# -*- coding: utf-8 -*-

"""
:parameter
--------------------
data: n-array like
[
[1.0 2.3 2.1 0.2]
[0.0 2.4 1.1 0.7]
]
每个元素都是有表示距离的属性的，对于没有距离属性的要抓化成具有距离属性的
"""

from sklearn.cluster import KMeans, MiniBatchKMeans
from sklearn.preprocessing import StandardScaler, MinMaxScaler
from sklearn.model_selection import train_test_split
from sklearn.manifold import TSNE
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt 
from mpl_toolkits.mplot3d import axes3d
from mpl_toolkits.mplot3d import Axes3D
from geopy.distance import geodesic


dir_name = '/Users/changqingli/data/time_space_cluster/'
feat_file_mini = 'fs_mini'
feat_file_all = 'fs_all'  # time,lant,long,geohash,buname
feat_file_user_shanghai_mini = 'fs_user_shanghai_mini'
feat_file_user_shanghai_all = 'fs_user_shanghai_all'  # userid,time,lant,long,geohash,buname
feat_file_user_consume_shanghai_mini = 'fs_user_consume_mini'  # 32398964 2019-09-13 12:49:40 31.226408 121.49096 到餐 春风松月楼素菜馆 dining 城隍庙/豫园 1


def key_count(cluster_y):
    m = {}
    for i in cluster_y:
        if i not in m:
            m.setdefault(i, 0)
        m[i] += 1
    res = sorted(m.items(), key=lambda x: x[1], reverse=True)
    return res

# %%
f_data = []
user_info = {}
hour_info = {}
user_base = []
consume_poi_type = {}
consume_poi_type_time = {}
consume_poi_lbs = []

with open(dir_name + feat_file_user_consume_shanghai_mini, 'r') as f:
    for line in f:
        line = line.strip().split("\t")
        if float(line[2])<30.40 or float(line[2])>31.53 or float(line[3])<120.52 or float(line[3])>122.12:
            continue
        line.insert(2, line[1][:4])  # _year
        line.insert(2, line[1][5:7])  # _month
        line.insert(2, line[1][8:10])  # _date
        line.insert(2, line[1][11:13])  # _hour
        
        if line[2] not in consume_poi_type:
            consume_poi_type[line[2]] = {}
        if line[-3] not in consume_poi_type[line[2]]:
            consume_poi_type[line[2]][line[-3]] = 0
        consume_poi_type[line[2]][line[-3]] += 1
        
        if line[-3] not in consume_poi_type_time:
            consume_poi_type_time[line[-3]] = {}
        if line[2] not in consume_poi_type_time[line[-3]]:
            consume_poi_type_time[line[-3]][line[2]] = 0
        consume_poi_type_time[line[-3]][line[2]] += 1
        
        consume_poi_lbs.append(line[6:8])

# %%
consume_poi_lbs[:2]
# Out:
# [['31.004527', '121.234578'], ['31.004527', '121.234578']]

# %%
consume_poi_type['16']
# Out:
# {'dining': 591,
#  'entertainment': 9,
#  'other': 73,
#  'Office Building': 102,
#  'mall': 127,
#  'hospital': 34,
#  'bank': 38,
#  'government': 28,
#  'hotel': 62,
#  'road': 1,
#  'Residential Area': 12,
#  'college': 2}

# %%
consume_poi_type_time['subway'].keys()
# Out:
# dict_keys(['15', '14'])

# %%
a = {i : sorted(consume_poi_type[i].items(), key=lambda x: x[1], reverse=True) for i in consume_poi_type}
a = sorted(a.items(), key=lambda x: x[0], reverse=False)
a
# Out:
# [('00',
#   [('dining', 116),
#    ('Office Building', 73),
#    ('hotel', 45),
#    ('other', 30),
#    ('government', 22),
#    ('hospital', 13),
#    ('bank', 10),
#    ('mall', 8),
#    ('college', 3),
#    ('Residential Area', 2),
#    ('entertainment', 2)]),
#  ('01',
#   [('dining', 52),
#    ('Office Building', 35),
#    ('bank', 16),
#    ('other', 15),
#    ('hotel', 7),
#    ('government', 6),
#    ('mall', 4)]),
#  ('02', [('dining', 13), ('mall', 4), ('bank', 3), ('hospital', 3)]),
#  ('03', [('Office Building', 36), ('bank', 14), ('dining', 7)]),
#  ('04', [('other', 6)]),
#  ('05', [('other', 4), ('bank', 2)]),
#  ('06', [('dining', 1)]),
#  ('07', [('dining', 2), ('hotel', 2)]),
#  ('08', [('dining', 19), ('mall', 16), ('Residential Area', 4), ('bank', 4)]),
#  ('09',
#   [('dining', 50),
#    ('Office Building', 18),
#    ('other', 10),
#    ('hotel', 10),
#    ('mall', 9),
#    ('Residential Area', 4),
#    ('hospital', 3),
#    ('bank', 2),
#    ('government', 1),
#    ('entertainment', 1)]),
#  ('10',
#   [('dining', 295),
#    ('Office Building', 47),
#    ('mall', 42),
#    ('other', 41),
#    ('bank', 11),
#    ('hotel', 5),
#    ('Residential Area', 5),
#    ('hospital', 3),
#    ('road', 2)]),
#  ('11',
#   [('dining', 618),
#    ('mall', 108),
#    ('Office Building', 97),
#    ('other', 77),
#    ('hotel', 64),
#    ('bank', 30),
#    ('Residential Area', 13),
#    ('government', 12),
#    ('hospital', 9),
#    ('entertainment', 5),
#    ('college', 3),
#    ('road', 1)]),
#  ('12',
#   [('dining', 1181),
#    ('mall', 258),
#    ('Office Building', 225),
#    ('hotel', 204),
#    ('other', 204),
#    ('bank', 41),
#    ('government', 19),
#    ('hospital', 16),
#    ('Residential Area', 10),
#    ('entertainment', 5),
#    ('college', 1)]),
#  ('13',
#   [('dining', 1745),
#    ('other', 349),
#    ('Office Building', 306),
#    ('mall', 295),
#    ('bank', 102),
#    ('hotel', 93),
#    ('government', 41),
#    ('hospital', 29),
#    ('entertainment', 22),
#    ('Residential Area', 6),
#    ('college', 2),
#    ('road', 2)]),
#  ('14',
#   [('dining', 1145),
#    ('other', 389),
#    ('mall', 268),
#    ('Office Building', 197),
#    ('bank', 89),
#    ('hospital', 69),
#    ('hotel', 46),
#    ('government', 39),
#    ('Residential Area', 17),
#    ('entertainment', 12),
#    ('college', 5),
#    ('subway', 1),
#    ('road', 1)]),
#  ('15',
#   [('dining', 670),
#    ('other', 256),
#    ('Office Building', 246),
#    ('mall', 131),
#    ('hotel', 54),
#    ('bank', 48),
#    ('government', 28),
#    ('hospital', 13),
#    ('entertainment', 11),
#    ('Residential Area', 9),
#    ('college', 5),
#    ('subway', 1)]),
#  ('16',
#   [('dining', 591),
#    ('mall', 127),
#    ('Office Building', 102),
#    ('other', 73),
#    ('hotel', 62),
#    ('bank', 38),
#    ('hospital', 34),
#    ('government', 28),
#    ('Residential Area', 12),
#    ('entertainment', 9),
#    ('college', 2),
#    ('road', 1)]),
#  ('17',
#   [('dining', 826),
#    ('Office Building', 176),
#    ('other', 172),
#    ('mall', 152),
#    ('bank', 42),
#    ('hotel', 42),
#    ('government', 23),
#    ('Residential Area', 12),
#    ('hospital', 12),
#    ('entertainment', 10),
#    ('college', 3),
#    ('road', 1)]),
#  ('18',
#   [('dining', 1541),
#    ('other', 271),
#    ('mall', 258),
#    ('Office Building', 227),
#    ('hotel', 75),
#    ('bank', 69),
#    ('government', 29),
#    ('Residential Area', 17),
#    ('entertainment', 12),
#    ('hospital', 10),
#    ('college', 4),
#    ('road', 1)]),
#  ('19',
#   [('dining', 1807),
#    ('other', 349),
#    ('mall', 329),
#    ('Office Building', 309),
#    ('bank', 118),
#    ('hotel', 89),
#    ('hospital', 62),
#    ('government', 34),
#    ('entertainment', 18),
#    ('Residential Area', 10),
#    ('college', 4),
#    ('PrimarySchool', 1)]),
#  ('20',
#   [('dining', 2257),
#    ('other', 384),
#    ('mall', 253),
#    ('Office Building', 252),
#    ('bank', 91),
#    ('hotel', 54),
#    ('hospital', 44),
#    ('entertainment', 17),
#    ('government', 14),
#    ('Residential Area', 10),
#    ('college', 4)]),
#  ('21',
#   [('dining', 631),
#    ('other', 231),
#    ('Office Building', 128),
#    ('hotel', 48),
#    ('mall', 47),
#    ('government', 24),
#    ('bank', 23),
#    ('hospital', 21),
#    ('entertainment', 16),
#    ('college', 4),
#    ('Residential Area', 2),
#    ('PrimarySchool', 1)]),
#  ('22',
#   [('dining', 252),
#    ('other', 86),
#    ('Office Building', 62),
#    ('hotel', 38),
#    ('mall', 34),
#    ('bank', 20),
#    ('government', 12),
#    ('college', 4),
#    ('hospital', 4)]),
#  ('23',
#   [('dining', 176),
#    ('other', 54),
#    ('Office Building', 51),
#    ('mall', 31),
#    ('bank', 31),
#    ('hotel', 21),
#    ('hospital', 19),
#    ('government', 14),
#    ('college', 2),
#    ('Residential Area', 1)])]

# %%
b = {i : sorted(consume_poi_type_time[i].items(), key=lambda x: x[1], reverse=True) for i in consume_poi_type_time}
b = sorted(b.items(), key=lambda x: x[0], reverse=False)
b
# Out:
# [('Office Building',
#   [('19', 309),
#    ('13', 306),
#    ('20', 252),
#    ('15', 246),
#    ('18', 227),
#    ('12', 225),
#    ('14', 197),
#    ('17', 176),
#    ('21', 128),
#    ('16', 102),
#    ('11', 97),
#    ('00', 73),
#    ('22', 62),
#    ('23', 51),
#    ('10', 47),
#    ('03', 36),
#    ('01', 35),
#    ('09', 18)]),
#  ('PrimarySchool', [('19', 1), ('21', 1)]),
#  ('Residential Area',
#   [('14', 17),
#    ('18', 17),
#    ('11', 13),
#    ('17', 12),
#    ('16', 12),
#    ('19', 10),
#    ('12', 10),
#    ('20', 10),
#    ('15', 9),
#    ('13', 6),
#    ('10', 5),
#    ('08', 4),
#    ('09', 4),
#    ('00', 2),
#    ('21', 2),
#    ('23', 1)]),
#  ('bank',
#   [('19', 118),
#    ('13', 102),
#    ('20', 91),
#    ('14', 89),
#    ('18', 69),
#    ('15', 48),
#    ('17', 42),
#    ('12', 41),
#    ('16', 38),
#    ('23', 31),
#    ('11', 30),
#    ('21', 23),
#    ('22', 20),
#    ('01', 16),
#    ('03', 14),
#    ('10', 11),
#    ('00', 10),
#    ('08', 4),
#    ('02', 3),
#    ('05', 2),
#    ('09', 2)]),
#  ('college',
#   [('14', 5),
#    ('15', 5),
#    ('18', 4),
#    ('20', 4),
#    ('19', 4),
#    ('22', 4),
#    ('21', 4),
#    ('00', 3),
#    ('17', 3),
#    ('11', 3),
#    ('13', 2),
#    ('23', 2),
#    ('16', 2),
#    ('12', 1)]),
#  ('dining',
#   [('20', 2257),
#    ('19', 1807),
#    ('13', 1745),
#    ('18', 1541),
#    ('12', 1181),
#    ('14', 1145),
#    ('17', 826),
#    ('15', 670),
#    ('21', 631),
#    ('11', 618),
#    ('16', 591),
#    ('10', 295),
#    ('22', 252),
#    ('23', 176),
#    ('00', 116),
#    ('01', 52),
#    ('09', 50),
#    ('08', 19),
#    ('02', 13),
#    ('03', 7),
#    ('07', 2),
#    ('06', 1)]),
#  ('entertainment',
#   [('13', 22),
#    ('19', 18),
#    ('20', 17),
#    ('21', 16),
#    ('18', 12),
#    ('14', 12),
#    ('15', 11),
#    ('17', 10),
#    ('16', 9),
#    ('11', 5),
#    ('12', 5),
#    ('00', 2),
#    ('09', 1)]),
#  ('government',
#   [('13', 41),
#    ('14', 39),
#    ('19', 34),
#    ('18', 29),
#    ('16', 28),
#    ('15', 28),
#    ('21', 24),
#    ('17', 23),
#    ('00', 22),
#    ('12', 19),
#    ('20', 14),
#    ('23', 14),
#    ('11', 12),
#    ('22', 12),
#    ('01', 6),
#    ('09', 1)]),
#  ('hospital',
#   [('14', 69),
#    ('19', 62),
#    ('20', 44),
#    ('16', 34),
#    ('13', 29),
#    ('21', 21),
#    ('23', 19),
#    ('12', 16),
#    ('00', 13),
#    ('15', 13),
#    ('17', 12),
#    ('18', 10),
#    ('11', 9),
#    ('22', 4),
#    ('02', 3),
#    ('09', 3),
#    ('10', 3)]),
#  ('hotel',
#   [('12', 204),
#    ('13', 93),
#    ('19', 89),
#    ('18', 75),
#    ('11', 64),
#    ('16', 62),
#    ('15', 54),
#    ('20', 54),
#    ('21', 48),
#    ('14', 46),
#    ('00', 45),
#    ('17', 42),
#    ('22', 38),
#    ('23', 21),
#    ('09', 10),
#    ('01', 7),
#    ('10', 5),
#    ('07', 2)]),
#  ('mall',
#   [('19', 329),
#    ('13', 295),
#    ('14', 268),
#    ('12', 258),
#    ('18', 258),
#    ('20', 253),
#    ('17', 152),
#    ('15', 131),
#    ('16', 127),
#    ('11', 108),
#    ('21', 47),
#    ('10', 42),
#    ('22', 34),
#    ('23', 31),
#    ('08', 16),
#    ('09', 9),
#    ('00', 8),
#    ('02', 4),
#    ('01', 4)]),
#  ('other',
#   [('14', 389),
#    ('20', 384),
#    ('19', 349),
#    ('13', 349),
#    ('18', 271),
#    ('15', 256),
#    ('21', 231),
#    ('12', 204),
#    ('17', 172),
#    ('22', 86),
#    ('11', 77),
#    ('16', 73),
#    ('23', 54),
#    ('10', 41),
#    ('00', 30),
#    ('01', 15),
#    ('09', 10),
#    ('04', 6),
#    ('05', 4)]),
#  ('road',
#   [('10', 2),
#    ('13', 2),
#    ('11', 1),
#    ('16', 1),
#    ('18', 1),
#    ('14', 1),
#    ('17', 1)]),
#  ('subway', [('15', 1), ('14', 1)])]

# %%
poi_type = 'mall'
print(poi_type)
for i in range(len(b)):
    if b[i][0] == poi_type:
        for j in b[i][1]:
            print(j)
# Out:
# mall
# ('19', 329)
# ('13', 295)
# ('14', 268)
# ('12', 258)
# ('18', 258)
# ('20', 253)
# ('17', 152)
# ('15', 131)
# ('16', 127)
# ('11', 108)
# ('21', 47)
# ('10', 42)
# ('22', 34)
# ('23', 31)
# ('08', 16)
# ('09', 9)
# ('00', 8)
# ('02', 4)
# ('01', 4)

# %%
np.shape(consume_poi_lbs)
# Out:
# (24763, 2)

# %%
# f_data_tmp = consume_poi_lbs
f_data_tmp = np.array(consume_poi_lbs)
f_data = f_data_tmp
scale = MinMaxScaler()
scale.fit(f_data)
f_data_transform = scale.transform(f_data)

# %%
np.array(f_data_transform, dtype='float')[:2]
# Out:
# array([[0.40918044, 0.20712993],
#        [0.40918044, 0.20712993]])

# %%
# plt.figure(figsize=(7, 7), dpi=80)
# axes = plt.subplot(111)
# for i in range(len(f_data_transform)):
#     axes.scatter(f_data_transform[i][4], f_data_transform[i][5], s=20)
# plt.show()

# %%
f_data_transform[:2]
# Out:
# array([[0.40918044, 0.20712993],
#        [0.40918044, 0.20712993]])

# %%
k_means = KMeans()
k_means.fit(f_data_transform)
cluster_train_counts = key_count(k_means.labels_)
print(cluster_train_counts)
# Out:
# [(3, 7689), (1, 5393), (7, 3884), (0, 3741), (2, 1762), (6, 1317), (5, 827), (4, 150)]

# %%
test_label = np.reshape(k_means.labels_, [len(k_means.labels_), -1])

# %%
# cluster_test = np.concatenate((np.reshape(f_data_tmp[:, 0], [len(f_data_tmp), 1]), f_data_transform[:, 4:], test_label.reshape([len(test_label), 1])), axis=1)
# df=pd.DataFrame(cluster_test, columns=['userid', 'f_0', 'f_1', 'label']) #转换数据格式

cluster_test = np.concatenate((f_data_transform, test_label.reshape([len(test_label), 1])), axis=1)
df=pd.DataFrame(cluster_test, columns=['f_0', 'f_1', 'label']) #转换数据格式


# df['userid'] = df['userid'].astype("int")
df['f_0'] = df['f_0'].astype("float")
df['f_1'] = df['f_1'].astype("float")
df['label'] = df['label'].astype("int")


df.dtypes
# Out:
# f_0      float64
# f_1      float64
# label      int64
# dtype: object

# %%
colr = ['#E15759', '#4E79A7', '#76B7B2', '#F28E2B','blue','#F45E2B','#F67E2B', 'r']

plt.figure(figsize=(7, 7), dpi=80)
axes = plt.subplot(111)
types = []
nums = []
for i in range(8):
    ii = str(i)
    d=df[df['label']==i]
    print("label %d has %d sample" % (i, len(d['f_1'].values)))
    type1 = axes.scatter(d['f_0'].values, d['f_1'].values, s=20, c=colr[i])
    types.append(type1)
    nums.append(str(i) + '_' + str(len(d['f_1'].values)))
axes.legend(types, nums, loc=2)

d=df[df['label']==2]
# Out:
# label 0 has 3741 sample
# label 1 has 5393 sample
# label 2 has 1762 sample
# label 3 has 7689 sample
# label 4 has 150 sample
# label 5 has 827 sample
# label 6 has 1317 sample
# label 7 has 3884 sample

# %%
df_temp = df[df['label']==1]
"""
7-上海市闵行区华光路
6-上海市虹口区衡水路89弄-4-～5号
3-上海市浦东新区金海路1255号
1-上海市嘉定区嘉定工业区胜辛社区东南方向
"""
df_temp.head()

f_0_mean = float(df_temp['f_0'].mean())
f_1_mean = float(df_temp['f_1'].mean())

max_f_0 = float(max(f_data[:, 4]))
min_f_0 = float(min(f_data[:, 4]))
max_f_1 = float(max(f_data[:, 5]))
min_f_1 = float(min(f_data[:, 5]))

f_0_mean_origin = f_0_mean * (max_f_0 - min_f_0) + min_f_0
f_1_mean_origin = f_1_mean * (max_f_1 - min_f_1) + min_f_1

print(f_0_mean_origin)
print(f_1_mean_origin)

# %%
f_data_transform_cluster = np.concatenate((f_data_transform, test_label.reshape([len(test_label), 1])), axis=1)
df1=pd.DataFrame(f_data_transform_cluster, columns=['f_0', 'f_1', 'f_2', 'f_3', 'f_4', 'f_5', 'label']) #转换数据格式


colr = ['#E15759', '#4E79A7', '#76B7B2', '#F28E2B','blue','#F45E2B','#F67E2B', 'r']
fig = plt.figure()
ax = Axes3D(fig)
types = []
nums = []
for i in range(8):
    d=df1[df1['label']==i]
    print("label %d has %d sample" % (i, len(d['f_1'].values)))
    type1 = ax.scatter(d['f_4'].values, d['f_5'].values, d['f_0'].values, s=20, c=colr[i])
    types.append(type1)
    nums.append(str(i) + str(len(d['f_1'].values)))
axes.legend(types, nums, loc=1)

d=df[df['label']==2]

 
ax.set_zlabel('T', fontdict={'size': 15, 'color': 'red'})
ax.set_ylabel('LAT', fontdict={'size': 15, 'color': 'red'})
ax.set_xlabel('LON', fontdict={'size': 15, 'color': 'red'})

plt.show()

# %%
# !pwd
