# %%
#!/usr/bin/env python
# -*- coding: utf-8 -*-

"""
:parameter
--------------------
data: n-array like
[
[1.0 2.3 2.1 0.2]
[0.0 2.4 1.1 0.7]
]
每个元素都是有表示距离的属性的，对于没有距离属性的要抓化成具有距离属性的
"""

from sklearn.cluster import KMeans, MiniBatchKMeans
from sklearn.preprocessing import StandardScaler, MinMaxScaler
from sklearn.model_selection import train_test_split
from sklearn.manifold import TSNE
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt 
from mpl_toolkits.mplot3d import axes3d
from mpl_toolkits.mplot3d import Axes3D


dir_name = '/Users/changqingli/data/time_space_cluster/'
feat_file_mini = 'fs_mini'
feat_file_all = 'fs_all'  # time,lant,long,geohash,buname
feat_file_user_shanghai_mini = 'fs_user_shanghai_mini'
feat_file_user_shanghai_all = 'fs_user_shanghai_all'  # userid,time,lant,long,geohash,buname


def key_count(cluster_y):
    m = {}
    for i in cluster_y:
        if i not in m:
            m.setdefault(i, 0)
        m[i] += 1
    res = sorted(m.items(), key=lambda x: x[1], reverse=True)
    return res

# %%
f_data = []
user_info = {}
hour_info = {}
user_base = []

with open(dir_name + feat_file_user_shanghai_mini, 'r') as f:
    for line in f:
        line = line.strip().split("\t")
        if float(line[-4])<30.40 or float(line[-4])>31.53 or float(line[-3])<120.52 or float(line[-3])>122.12:
            continue
        bu_name = line[-1]
        line.insert(2, line[1][:4])  # _year
        line.insert(2, line[1][5:7])  # _month
        line.insert(2, line[1][8:10])  # _date
        line.insert(2, line[1][11:13])  # _hour
        
        if line[-1] not in user_info:
            user_info[line[-1]] = []
        user_info[line[-1]].append(line[:-2])  # [_hour,_date,_month,_year,latitude,longitude]
        
        user_base.append([line[0], line[-1]])
        
        if line[2] not in hour_info:
            hour_info[line[2]] = {}
        if line[-1] not in hour_info[line[2]]:
            hour_info[line[2]][line[-1]] = []
        hour_info[line[2]][line[-1]].append(line[2:-2])

# %%
user_info.keys()
# Out:
# dict_keys(['外卖事业部', '住宿事业部', '闪购', '到餐', '猫眼文化', 'unknown', '休闲娱乐', '美团支付', '配送事业部', '丽人', '境内度假事业部', '榛果业务部', '大交通事业部', '亲子', '结婚'])

# %%
hour_info.keys()
# Out:
# dict_keys(['16', '19', '11', '10', '20', '09', '05', '08', '22', '23', '17', '14', '18', '21', '13', '15', '12', '04', '00', '01', '07', '03', '02', '06'])

# %%
f_data_tmp = user_info['到餐']
f_data_tmp = np.array(f_data_tmp)
f_data = f_data_tmp[:, 2:]
scale = MinMaxScaler()
scale.fit(f_data)
f_data_transform = scale.transform(f_data)

# %%
np.array(f_data, dtype='float')[:2]
# Out:
# array([[  13.      ,   21.      ,    9.      , 2019.      ,   31.301941,
#          121.505677],
#        [  11.      ,   21.      ,    9.      , 2019.      ,   31.300391,
#          121.513584]])

# %%
# plt.figure(figsize=(7, 7), dpi=80)
# axes = plt.subplot(111)
# for i in range(len(f_data_transform)):
#     axes.scatter(f_data_transform[i][4], f_data_transform[i][5], s=20)
# plt.show()

# %%
f_data_transform[:, 4:]
# Out:
# array([[0.83345177, 0.60518237],
#        [0.83118543, 0.61681829],
#        [0.77864435, 0.55728926],
#        ...,
#        [0.59252956, 0.49008732],
#        [0.59252956, 0.49008732],
#        [0.70379809, 0.4772859 ]])

# %%
x = np.array(f_data, dtype='float')[:, 4]
y = np.array(f_data, dtype='float')[:, 5]
z = np.array(f_data, dtype='float')[:, 0]

fig = plt.figure()
ax = Axes3D(fig)
ax.scatter(x, y, z)

ax.set_ylabel('Y', fontdict={'size': 15, 'color': 'red'})
ax.set_xlabel('X', fontdict={'size': 15, 'color': 'red'})
ax.set_zlabel('Z', fontdict={'size': 15, 'color': 'red'})

plt.show()

# %%
k_means = KMeans()
k_means.fit(f_data_transform[:, 4:])
cluster_train_counts = key_count(k_means.labels_)
print(cluster_train_counts)
# Out:
# [(6, 262), (3, 129), (1, 127), (7, 117), (0, 107), (5, 51), (2, 38), (4, 30)]

# %%
test_label = np.reshape(k_means.labels_, [len(k_means.labels_), -1])

# %%
cluster_test = np.concatenate((np.reshape(f_data_tmp[:, 0], [len(f_data_tmp), 1]), f_data_transform[:, 4:], test_label.reshape([len(test_label), 1])), axis=1)
df=pd.DataFrame(cluster_test, columns=['userid', 'f_0', 'f_1', 'label']) #转换数据格式

# cluster_test = np.concatenate((f_data_transform[:, 4:], test_label.reshape([len(test_label), 1])), axis=1)
# df=pd.DataFrame(cluster_test, columns=['f_0', 'f_1', 'label']) #转换数据格式


df['userid'] = df['userid'].astype("int")
df['f_0'] = df['f_0'].astype("float")
df['f_1'] = df['f_1'].astype("float")
df['label'] = df['label'].astype("int")


df.dtypes
# Out:
# userid      int64
# f_0       float64
# f_1       float64
# label       int64
# dtype: object

# %%
colr = ['#E15759', '#4E79A7', '#76B7B2', '#F28E2B','blue','#F45E2B','#F67E2B', 'r']

plt.figure(figsize=(7, 7), dpi=80)
axes = plt.subplot(111)
types = []
nums = []
for i in range(8):
    ii = str(i)
    d=df[df['label']==i]
    print("label %d has %d sample" % (i, len(d['f_1'].values)))
    type1 = axes.scatter(d['f_0'].values, d['f_1'].values, s=20, c=colr[i])
    types.append(type1)
    nums.append(str(i) + '_' + str(len(d['f_1'].values)))
axes.legend(types, nums, loc=1)

d=df[df['label']==2]
# Out:
# label 0 has 107 sample
# label 1 has 127 sample
# label 2 has 38 sample
# label 3 has 129 sample
# label 4 has 30 sample
# label 5 has 51 sample
# label 6 has 262 sample
# label 7 has 117 sample

# %%
df_temp = df[df['label']==1]
"""
7-上海市闵行区华光路
6-上海市虹口区衡水路89弄-4-～5号
3-上海市浦东新区金海路1255号
1-上海市嘉定区嘉定工业区胜辛社区东南方向
"""
df_temp.head()

f_0_mean = float(df_temp['f_0'].mean())
f_1_mean = float(df_temp['f_1'].mean())

max_f_0 = float(max(f_data[:, 4]))
min_f_0 = float(min(f_data[:, 4]))
max_f_1 = float(max(f_data[:, 5]))
min_f_1 = float(min(f_data[:, 5]))

f_0_mean_origin = f_0_mean * (max_f_0 - min_f_0) + min_f_0
f_1_mean_origin = f_1_mean * (max_f_1 - min_f_1) + min_f_1

print(f_0_mean_origin)
print(f_1_mean_origin)
# Out:
# 31.361548606299213
# 121.2394162519685

# %%
f_data_transform_cluster = np.concatenate((f_data_transform, test_label.reshape([len(test_label), 1])), axis=1)
df1=pd.DataFrame(f_data_transform_cluster, columns=['f_0', 'f_1', 'f_2', 'f_3', 'f_4', 'f_5', 'label']) #转换数据格式


colr = ['#E15759', '#4E79A7', '#76B7B2', '#F28E2B','blue','#F45E2B','#F67E2B', 'r']
fig = plt.figure()
ax = Axes3D(fig)
types = []
nums = []
for i in range(8):
    d=df1[df1['label']==i]
    print("label %d has %d sample" % (i, len(d['f_1'].values)))
    type1 = ax.scatter(d['f_4'].values, d['f_5'].values, d['f_0'].values, s=20, c=colr[i])
    types.append(type1)
    nums.append(str(i) + str(len(d['f_1'].values)))
axes.legend(types, nums, loc=1)

d=df[df['label']==2]

 
ax.set_zlabel('T', fontdict={'size': 15, 'color': 'red'})
ax.set_ylabel('LAT', fontdict={'size': 15, 'color': 'red'})
ax.set_xlabel('LON', fontdict={'size': 15, 'color': 'red'})

plt.show()
# Out:
# label 0 has 107 sample
# label 1 has 127 sample
# label 2 has 38 sample
# label 3 has 129 sample
# label 4 has 30 sample
# label 5 has 51 sample
# label 6 has 262 sample
# label 7 has 117 sample
